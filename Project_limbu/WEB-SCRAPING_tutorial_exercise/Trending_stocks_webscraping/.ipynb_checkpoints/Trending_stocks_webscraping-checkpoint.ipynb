# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url= 'https://www.tipranks.com/trending-stocks'

# %%
browser= webdriver.Chrome()

# %%
browser.get(url)

# %%
# Creating a CLASs that iterates over the Browser element
class get_element(object):
    
    # initializing
    # locator: to locate elements
    # n: to get the NUMBER of elements
    def __init__(self, locator, n):
        self.locator= locator
        self.n= n
        
    # call function for Iteration using the BROWSER to find element by LOCATING each WEB element
    def __call__(self, browser):
        
        element= browser.find_elements(*self.locator)
        
        # compare the number of elements
        if len(element) >= self.n:
            return element
        else:
            return False

# %%
# BROWSER waiting time
# WAIT for atleast 10 seconds
browser.implicitly_wait(10)

# %%
# LOCATE the searched CONTENTS wherre the ITERATION will take place
# DIV element from the Content
div_element= browser.find_element_by_xpath('//*[@id="app"]/div/div/main/div/div/div[2]/div[2]/div/div/div[1]/ul')

# %%
# LOCATE each INDIVIDUAL element from the WEB element

# stock INFO:
locator_stock_info= (By.CLASS_NAME,'client-components-ratings-trending-stock-row__stockInfo')

# stock Consensus 
locator_stock_consensus= (By.CLASS_NAME,'client-components-ratings-trending-stock-row__consensus')

# stock Target Price
locator_stoc_tgt_price= (By.CLASS_NAME, 'client-components-ratings-trending-stock-row__priceTarget')

# Stock Rating
locator_stock_weigth= (By.CLASS_NAME,'client-components-ratings-trending-stock-row__trendGraph')

# %%
# iteration of each element
stock_info_cnt=0
stock_cons_cnt= 0
stock_price_cnt= 0
stock_weight_cnt= 0

# RECORDS of empty list
stock_info_rec= []
stock_info_cons= []
stock_info_price= []
stock_weight_rec= []


# create while loop 
while True:
    
    # use browser script for iteration over the browser DIV element 
    browser.execute_script(
    'arguments[0].scrollTop= arguments[0].scrollHeight', div_element
    )
    
    # use TRY and catch error method to ITERATE using the CLASS 
    
    try:
        # RECORD each iteration and wait for 3 seconds until ITERATIng other element
        stock_info= WebDriverWait(browser, 3).until(
            # USING THe located elmenets from the SECtion
            get_element(locator_stock_info, stock_info_cnt +1)
        )
        
        # stock consesnus
        stock_cons= WebDriverWait(browser, 3).until(
            get_element(locator_stock_consensus, stock_cons_cnt +1)
        )
        
        # stock PRICE target
        stock_tgt_price= WebDriverWait(browser, 3).until(
            get_element(locator_stoc_tgt_price, stock_price_cnt +1)
        )
        
        # stock Weight cnt
        stock_wgt_total_cnt= WebDriverWait(browser, 3).until(
            get_element(locator_stock_weigth, stock_weight_cnt+ 1)
        )
        
    except TimeoutException as EC:
        break
        
    # update the COLLECTED record info UNLESS returns FALSE
    # number of RECORDS collected 
    stock_info_cnt= len(stock_info)
    stock_cons_cnt= len(stock_cons)
    stock_price_cnt= len(stock_tgt_price)
    stock_weight_cnt = len(stock_wgt_total_cnt)
    
    for single_stock_info in stock_info:
        stock_info_rec.append(single_stock_info.text)
        
    for single_stock_cons in stock_cons:
        stock_info_cons.append(single_stock_cons.text)
        
    for single_stock_price in stock_tgt_price:
        stock_info_price.append(single_stock_price.text)  
        
       
    for stock_weigh in stock_wgt_total_cnt:
        stock_weight_rec.append(stock_weigh.text)

# %%
# QUIT
browser.quit()

# %%
len(stock_info_price), len(stock_info_cons), len (stock_info_rec)
# Out:
# (21, 21, 21)

# %%
len(stock_weight_rec)
# Out:
# 21

# %%
stock_weight_rec
# Out:
# ['Ratings in \nLast 30 Days',
#  '27\n8 Buy\n18 Hold\n1 Sell',
#  '25\n22 Buy\n2 Hold\n1 Sell',
#  '22\n20 Buy\n2 Hold\n0 Sell',
#  '21\n8 Buy\n9 Hold\n4 Sell',
#  '17\n10 Buy\n5 Hold\n2 Sell',
#  '17\n14 Buy\n3 Hold\n0 Sell',
#  '17\n11 Buy\n5 Hold\n1 Sell',
#  '16\n5 Buy\n9 Hold\n2 Sell',
#  '15\n1 Buy\n14 Hold\n0 Sell',
#  '15\n11 Buy\n4 Hold\n0 Sell',
#  '14\n4 Buy\n10 Hold\n0 Sell',
#  '13\n6 Buy\n5 Hold\n2 Sell',
#  '13\n6 Buy\n6 Hold\n1 Sell',
#  '13\n12 Buy\n1 Hold\n0 Sell',
#  '13\n4 Buy\n9 Hold\n0 Sell',
#  '13\n7 Buy\n6 Hold\n0 Sell',
#  '12\n12 Buy\n0 Hold\n0 Sell',
#  '12\n9 Buy\n3 Hold\n0 Sell',
#  '12\n11 Buy\n1 Hold\n0 Sell',
#  '11\n10 Buy\n1 Hold\n0 Sell']

# %% [markdown]
# # Creating the DATAFRAME

# %%
df_stock_rec= pd.DataFrame({'Stock_info': stock_info_rec, 'Price_Target':stock_info_price, 'Consensus': stock_info_cons,'stock_weigh': stock_weight_rec })

# %%
df_stock_rec
# Out:
#                                            Stock_info           Price_Target  \
# 0                                             Company  Average\nPrice Target
# 1        3 days ago\nAirbnb(ABNB)\n169.2711.23(6.22%)                $154.88
# 2           13 days ago\nNike(NKE)\n140.720.58(0.41%)                $163.07
# 3            3 days ago\nMicron(MU)\n80.720.58(0.71%)                 $98.52
# 4           2 days ago\nIntel(INTC)\n57.581.67(2.82%)                 $57.00
# 5        2 days ago\nNetflix(NFLX)\n497.982.88(0.58%)                $583.52
# 6          3 days ago\nDarden(DRI)\n121.082.02(1.64%)                $127.25
# 7   5 days ago\nSarepta Therapeutics(SRPT)\n90.320...                $129.27
# 8         3 days ago\nTesla(TSLA)\n826.1618.84(2.23%)                $544.42
# 9   6 days ago\nChange Healthcare(CHNG)\n24.000.08...                 $24.66
# 10  9 days ago\nConstellation Brands(STZ)\n219.993...                $253.00
# 11        4 days ago\nTwitter(TWTR)\n45.180.61(1.33%)                 $51.08
# 12         2 days ago\nApple(AAPL)\n127.141.77(1.37%)                $133.00
# 13         2 days ago\nL Brands(LB)\n45.200.22(0.49%)                 $48.00
# 14  2 days ago\nPalo Alto Networks(PANW)\n364.871....                $372.67
# 15     3 days ago\nDoorDash(DASH)\n187.1520.09(9.69%)                $163.00
# 16         3 days ago\nZscaler(ZS)\n211.061.19(0.57%)                $208.94
# 17       2 days ago\nAlibaba(BABA)\n243.460.48(0.20%)                $330.94
# 18    4 days ago\nFive Below(FIVE)\n189.814.72(2.43%)                $194.50
# 19  4 days ago\nPeloton Interactive(PTON)\n157.817...                $154.00
# 20  3 days ago\nIAC/InterActive(IAC)\n197.661.23(0...                $199.31
#
#             Consensus                 stock_weigh
# 0   Overall Consensus   Ratings in \nLast 30 Days
# 1        Moderate Buy  27\n8 Buy\n18 Hold\n1 Sell
# 2          Strong Buy  25\n22 Buy\n2 Hold\n1 Sell
# 3          Strong Buy  22\n20 Buy\n2 Hold\n0 Sell
# 4                Hold   21\n8 Buy\n9 Hold\n4 Sell
# 5        Moderate Buy  17\n10 Buy\n5 Hold\n2 Sell
# 6        Moderate Buy  17\n14 Buy\n3 Hold\n0 Sell
# 7        Moderate Buy  17\n11 Buy\n5 Hold\n1 Sell
# 8                Hold   16\n5 Buy\n9 Hold\n2 Sell
# 9                Hold  15\n1 Buy\n14 Hold\n0 Sell
# 10       Moderate Buy  15\n11 Buy\n4 Hold\n0 Sell
# 11       Moderate Buy  14\n4 Buy\n10 Hold\n0 Sell
# 12       Moderate Buy   13\n6 Buy\n5 Hold\n2 Sell
# 13       Moderate Buy   13\n6 Buy\n6 Hold\n1 Sell
# 14         Strong Buy  13\n12 Buy\n1 Hold\n0 Sell
# 15       Moderate Buy   13\n4 Buy\n9 Hold\n0 Sell
# 16       Moderate Buy   13\n7 Buy\n6 Hold\n0 Sell
# 17         Strong Buy  12\n12 Buy\n0 Hold\n0 Sell
# 18         Strong Buy   12\n9 Buy\n3 Hold\n0 Sell
# 19         Strong Buy  12\n11 Buy\n1 Hold\n0 Sell
# 20         Strong Buy  11\n10 Buy\n1 Hold\n0 Sell

# %% [markdown]
# # Feature Engineering
# - Extract Stock symbols
# - Extract Stock Upgrade Time
# - Extract Stock Current Price
# - Change Data Type. EG: Stock Price (Object) --> Float

# %% [markdown]
# # REMOVING first index of Data Frame

# %%
df_stock_rec= df_stock_rec.drop(df_stock_rec.index[0])
df_stock_rec
# Out:
#                                            Stock_info Price_Target  \
# 1        3 days ago\nAirbnb(ABNB)\n169.2711.23(6.22%)      $154.88
# 2           13 days ago\nNike(NKE)\n140.720.58(0.41%)      $163.07
# 3            3 days ago\nMicron(MU)\n80.720.58(0.71%)       $98.52
# 4           2 days ago\nIntel(INTC)\n57.581.67(2.82%)       $57.00
# 5        2 days ago\nNetflix(NFLX)\n497.982.88(0.58%)      $583.52
# 6          3 days ago\nDarden(DRI)\n121.082.02(1.64%)      $127.25
# 7   5 days ago\nSarepta Therapeutics(SRPT)\n90.320...      $129.27
# 8         3 days ago\nTesla(TSLA)\n826.1618.84(2.23%)      $544.42
# 9   6 days ago\nChange Healthcare(CHNG)\n24.000.08...       $24.66
# 10  9 days ago\nConstellation Brands(STZ)\n219.993...      $253.00
# 11        4 days ago\nTwitter(TWTR)\n45.180.61(1.33%)       $51.08
# 12         2 days ago\nApple(AAPL)\n127.141.77(1.37%)      $133.00
# 13         2 days ago\nL Brands(LB)\n45.200.22(0.49%)       $48.00
# 14  2 days ago\nPalo Alto Networks(PANW)\n364.871....      $372.67
# 15     3 days ago\nDoorDash(DASH)\n187.1520.09(9.69%)      $163.00
# 16         3 days ago\nZscaler(ZS)\n211.061.19(0.57%)      $208.94
# 17       2 days ago\nAlibaba(BABA)\n243.460.48(0.20%)      $330.94
# 18    4 days ago\nFive Below(FIVE)\n189.814.72(2.43%)      $194.50
# 19  4 days ago\nPeloton Interactive(PTON)\n157.817...      $154.00
# 20  3 days ago\nIAC/InterActive(IAC)\n197.661.23(0...      $199.31
#
#        Consensus                 stock_weigh
# 1   Moderate Buy  27\n8 Buy\n18 Hold\n1 Sell
# 2     Strong Buy  25\n22 Buy\n2 Hold\n1 Sell
# 3     Strong Buy  22\n20 Buy\n2 Hold\n0 Sell
# 4           Hold   21\n8 Buy\n9 Hold\n4 Sell
# 5   Moderate Buy  17\n10 Buy\n5 Hold\n2 Sell
# 6   Moderate Buy  17\n14 Buy\n3 Hold\n0 Sell
# 7   Moderate Buy  17\n11 Buy\n5 Hold\n1 Sell
# 8           Hold   16\n5 Buy\n9 Hold\n2 Sell
# 9           Hold  15\n1 Buy\n14 Hold\n0 Sell
# 10  Moderate Buy  15\n11 Buy\n4 Hold\n0 Sell
# 11  Moderate Buy  14\n4 Buy\n10 Hold\n0 Sell
# 12  Moderate Buy   13\n6 Buy\n5 Hold\n2 Sell
# 13  Moderate Buy   13\n6 Buy\n6 Hold\n1 Sell
# 14    Strong Buy  13\n12 Buy\n1 Hold\n0 Sell
# 15  Moderate Buy   13\n4 Buy\n9 Hold\n0 Sell
# 16  Moderate Buy   13\n7 Buy\n6 Hold\n0 Sell
# 17    Strong Buy  12\n12 Buy\n0 Hold\n0 Sell
# 18    Strong Buy   12\n9 Buy\n3 Hold\n0 Sell
# 19    Strong Buy  12\n11 Buy\n1 Hold\n0 Sell
# 20    Strong Buy  11\n10 Buy\n1 Hold\n0 Sell

# %%
import re # Regular Expression COMPILER

# %% [markdown]
# # EXMPLE of RAW DATA

# %%
MU= df_stock_rec.iloc[2, 0]
MU
# Out:
# '3 days ago\nMicron(MU)\n80.720.58(0.71%)'

# %% [markdown]
# # Creating a Function that will COMPILE and MANIPULATE the STRINGS that has been EXTRACTED

# %% [markdown]
# # 1. Stock Symbol Extract

# %%
def extract_sym(stk):
    
    # checks over the strings that are UPPERCASE repeated Consecutively
    split_wd= re.compile('\(+[A-Z]+\)')
    symbl= split_wd.findall(stk)

    # Stored on LIST
    symbl_extracted= symbl[0]

    # Replace any Signs
    new_sym= symbl_extracted.replace('(','')
    new_sym= new_sym.replace(')','')
    return new_sym

# %%
stk_id= df_stock_rec.iloc[8, 0]
extract_sym(stk_id)
# Out:
# 'CHNG'

# %%
# EMPTY list for STOCK symbols


stock_symbol= []

for stock_num in range(len(df_stock_rec)):
   
    stock_id= df_stock_rec.iloc[stock_num, 0]
    # adding the SYMBOLS in a new LIST
    stock_symbol.append(extract_sym(stock_id))

# %%
stock_symbol
# Out:
# ['ABNB',
#  'NKE',
#  'MU',
#  'INTC',
#  'NFLX',
#  'DRI',
#  'SRPT',
#  'TSLA',
#  'CHNG',
#  'STZ',
#  'TWTR',
#  'AAPL',
#  'LB',
#  'PANW',
#  'DASH',
#  'ZS',
#  'BABA',
#  'FIVE',
#  'PTON',
#  'IAC']

# %% [markdown]
# # CREATING a new column on DATA FRAME

# %%
df_stock_rec['stock']= pd.Series(stock_symbol, index= df_stock_rec.index)

# %%
df_stock_rec.iloc[0, 1]
# Out:
# '$154.88'

# %% [markdown]
# # REMOVE expression from Price_Target Column
# # Change the Data Type of 'Price_Target' Column

# %%
# REMOVE '$' SIGN 

for dollar in range(len(df_stock_rec['Price_Target'])):
    df_stock_rec['Price_Target']= df_stock_rec['Price_Target'].str.replace('$','')

# %%
df_stock_rec
# Out:
#                                            Stock_info Price_Target  \
# 1        3 days ago\nAirbnb(ABNB)\n169.2711.23(6.22%)       154.88
# 2           13 days ago\nNike(NKE)\n140.720.58(0.41%)       163.07
# 3            3 days ago\nMicron(MU)\n80.720.58(0.71%)        98.52
# 4           2 days ago\nIntel(INTC)\n57.581.67(2.82%)        57.00
# 5        2 days ago\nNetflix(NFLX)\n497.982.88(0.58%)       583.52
# 6          3 days ago\nDarden(DRI)\n121.082.02(1.64%)       127.25
# 7   5 days ago\nSarepta Therapeutics(SRPT)\n90.320...       129.27
# 8         3 days ago\nTesla(TSLA)\n826.1618.84(2.23%)       544.42
# 9   6 days ago\nChange Healthcare(CHNG)\n24.000.08...        24.66
# 10  9 days ago\nConstellation Brands(STZ)\n219.993...       253.00
# 11        4 days ago\nTwitter(TWTR)\n45.180.61(1.33%)        51.08
# 12         2 days ago\nApple(AAPL)\n127.141.77(1.37%)       133.00
# 13         2 days ago\nL Brands(LB)\n45.200.22(0.49%)        48.00
# 14  2 days ago\nPalo Alto Networks(PANW)\n364.871....       372.67
# 15     3 days ago\nDoorDash(DASH)\n187.1520.09(9.69%)       163.00
# 16         3 days ago\nZscaler(ZS)\n211.061.19(0.57%)       208.94
# 17       2 days ago\nAlibaba(BABA)\n243.460.48(0.20%)       330.94
# 18    4 days ago\nFive Below(FIVE)\n189.814.72(2.43%)       194.50
# 19  4 days ago\nPeloton Interactive(PTON)\n157.817...       154.00
# 20  3 days ago\nIAC/InterActive(IAC)\n197.661.23(0...       199.31
#
#        Consensus                 stock_weigh stock
# 1   Moderate Buy  27\n8 Buy\n18 Hold\n1 Sell  ABNB
# 2     Strong Buy  25\n22 Buy\n2 Hold\n1 Sell   NKE
# 3     Strong Buy  22\n20 Buy\n2 Hold\n0 Sell    MU
# 4           Hold   21\n8 Buy\n9 Hold\n4 Sell  INTC
# 5   Moderate Buy  17\n10 Buy\n5 Hold\n2 Sell  NFLX
# 6   Moderate Buy  17\n14 Buy\n3 Hold\n0 Sell   DRI
# 7   Moderate Buy  17\n11 Buy\n5 Hold\n1 Sell  SRPT
# 8           Hold   16\n5 Buy\n9 Hold\n2 Sell  TSLA
# 9           Hold  15\n1 Buy\n14 Hold\n0 Sell  CHNG
# 10  Moderate Buy  15\n11 Buy\n4 Hold\n0 Sell   STZ
# 11  Moderate Buy  14\n4 Buy\n10 Hold\n0 Sell  TWTR
# 12  Moderate Buy   13\n6 Buy\n5 Hold\n2 Sell  AAPL
# 13  Moderate Buy   13\n6 Buy\n6 Hold\n1 Sell    LB
# 14    Strong Buy  13\n12 Buy\n1 Hold\n0 Sell  PANW
# 15  Moderate Buy   13\n4 Buy\n9 Hold\n0 Sell  DASH
# 16  Moderate Buy   13\n7 Buy\n6 Hold\n0 Sell    ZS
# 17    Strong Buy  12\n12 Buy\n0 Hold\n0 Sell  BABA
# 18    Strong Buy   12\n9 Buy\n3 Hold\n0 Sell  FIVE
# 19    Strong Buy  12\n11 Buy\n1 Hold\n0 Sell  PTON
# 20    Strong Buy  11\n10 Buy\n1 Hold\n0 Sell   IAC

# %%
# Change Data Type of Price Target Values

for dollar in range(len(df_stock_rec['Price_Target'])):
    df_stock_rec['Price_Target']= df_stock_rec['Price_Target'].astype(float)

# %%
df_stock_rec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 1 to 20
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Stock_info    20 non-null     object
#  1   Price_Target  20 non-null     float64
#  2   Consensus     20 non-null     object
#  3   stock_weigh   20 non-null     object
#  4   stock         20 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 960.0+ bytes

# %% [markdown]
# # 2. Time of Stock Upgrade

# %% [markdown]
# # 3. Extract Actual/ Daily Stock Price

# %%
MU # EXAMPLE, info to EXTRACT
# Out:
# '3 days ago\nMicron(MU)\n80.720.58(0.71%)'

# %%
# pass the COLUMN in this function
def extract_actual_price(df_stk):
    # empty list to get Current Stk price
    curr_pr=[]   
    
    for stk in range(len(df_stk)):
        # ITERATE and SEARCH for the float value (DAILY Stock Price)
        stk_flt_pr= re.search('[+-]?[0-9]+\.[0-9]+',df_stk.iloc[stk, 0])
        
        # Load the First element on the LIST
        curr_pr.append(stk_flt_pr.group(0))
    
    return curr_pr
        
        # get EACH item by ITERATING throught the

# %%
MU
# Out:
# '3 days ago\nMicron(MU)\n80.720.58(0.71%)'

# %%
stk_flt_price= re.search('[+-]?[0-9]+\.[0-9]+', df_stock_rec.iloc[2, 0])
print(stk_flt_price)
# Out:
# <re.Match object; span=(22, 28), match='80.720'>

# %%
stk_flt_price.group(0)
# Out:
# '80.720'

# %% [markdown]
# # ADDING the ACTUAL/DAILY price on a new coulmn

# %%
# Change data TYPE of actual price
df_stock_rec['Daily_price']= extract_actual_price(df_stock_rec)

for dollar in range(len(df_stock_rec['Daily_price'])):
    df_stock_rec['Daily_price']= df_stock_rec['Daily_price'].astype(float)
    
    
df_stock_rec
# Out:
#                                            Stock_info  Price_Target  \
# 1        3 days ago\nAirbnb(ABNB)\n169.2711.23(6.22%)        154.88
# 2           13 days ago\nNike(NKE)\n140.720.58(0.41%)        163.07
# 15  Moderate Buy   13\n4 Buy\n9 Hold\n0 Sell  DASH     187.1520
# 16  Moderate Buy   13\n7 Buy\n6 Hold\n0 Sell    ZS     211.0610
# 17    Strong Buy  12\n12 Buy\n0 Hold\n0 Sell  BABA     243.4600
# 18    Strong Buy   12\n9 Buy\n3 Hold\n0 Sell  FIVE     189.8140
# 19    Strong Buy  12\n11 Buy\n1 Hold\n0 Sell  PTON     157.8170
# 20    Strong Buy  11\n10 Buy\n1 Hold\n0 Sell   IAC     197.6610

# %%
df_stock_rec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 1 to 20
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Stock_info    20 non-null     object
#  1   Price_Target  20 non-null     float64
#  2   Consensus     20 non-null     object
#  3   stock_weigh   20 non-null     object
#  4   stock         20 non-null     object
#  5   Daily_price   20 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 1.1+ KB

# %% [markdown]
# # USING label ENCODER to encode the Sock Consensus

# %%
df_stock_rec.iloc[0, 2]
# Out:
# 'Moderate Buy'

# %% [markdown]
# # Convert Stock RATING

# %%
w= ['Moderate Buy', 'Strong Buy', 'Hold']
for stk in range(len(df_stock_rec['Consensus'])):
    
    if (df_stock_rec.iloc[stk, 2] == w[0]):
        df_stock_rec= df_stock_rec.replace(df_stock_rec.iloc[stk, 2], 'M')
    elif (df_stock_rec.iloc[stk, 2] == w[1]):
        df_stock_rec= df_stock_rec.replace(df_stock_rec.iloc[stk, 2], 'S')
    elif (df_stock_rec.iloc[stk, 2] == w[2]):
        df_stock_rec= df_stock_rec.replace(df_stock_rec.iloc[stk, 2], 'H')

        
# CONVERSION to strings
for stk in range(len(df_stock_rec['Consensus'])):
    df_stock_rec['Consensus']= df_stock_rec['Consensus'].astype(str)

# %%
df_stock_rec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 1 to 20
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Stock_info    20 non-null     object
#  1   Price_Target  20 non-null     float64
#  2   Consensus     20 non-null     object
#  3   stock_weigh   20 non-null     object
#  4   stock         20 non-null     object
#  5   Daily_price   20 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 1.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

label_en= LabelEncoder()
#label_one_hot= OneHotEncoder()

# CREATE new column 
analyst_wgh= label_en.fit_transform(df_stock_rec['Consensus'])

df_stock_rec['Analyst_weigh']= analyst_wgh
df_stock_rec
# Out:
#                                            Stock_info  Price_Target Consensus  \
# 1        3 days ago\nAirbnb(ABNB)\n169.2711.23(6.22%)        154.88         M
# 2           13 days ago\nNike(NKE)\n140.720.58(0.41%)        163.07         S
# 3            3 days ago\nMicron(MU)\n80.720.58(0.71%)         98.52         S
# 4           2 days ago\nIntel(INTC)\n57.581.67(2.82%)         57.00         H
# 5        2 days ago\nNetflix(NFLX)\n497.982.88(0.58%)        583.52         M
# 6          3 days ago\nDarden(DRI)\n121.082.02(1.64%)        127.25         M
# 7   5 days ago\nSarepta Therapeutics(SRPT)\n90.320...        129.27         M
# 8         3 days ago\nTesla(TSLA)\n826.1618.84(2.23%)        544.42         H
# 9   6 days ago\nChange Healthcare(CHNG)\n24.000.08...         24.66         H
# 10  9 days ago\nConstellation Brands(STZ)\n219.993...        253.00         M
# 11        4 days ago\nTwitter(TWTR)\n45.180.61(1.33%)         51.08         M
# 12         2 days ago\nApple(AAPL)\n127.141.77(1.37%)        133.00         M
# 13         2 days ago\nL Brands(LB)\n45.200.22(0.49%)         48.00         M
# 14  2 days ago\nPalo Alto Networks(PANW)\n364.871....        372.67         S
# 15     3 days ago\nDoorDash(DASH)\n187.1520.09(9.69%)        163.00         M
# 16         3 days ago\nZscaler(ZS)\n211.061.19(0.57%)        208.94         M
# 17       2 days ago\nAlibaba(BABA)\n243.460.48(0.20%)        330.94         S
# 18    4 days ago\nFive Below(FIVE)\n189.814.72(2.43%)        194.50         S
# 19  4 days ago\nPeloton Interactive(PTON)\n157.817...        154.00         S
# 20  3 days ago\nIAC/InterActive(IAC)\n197.661.23(0...        199.31         S
#
#                    stock_weigh stock  Daily_price  Analyst_weigh
# 1   27\n8 Buy\n18 Hold\n1 Sell  ABNB     169.2711              1
# 2   25\n22 Buy\n2 Hold\n1 Sell   NKE     140.7200              2
# 3   22\n20 Buy\n2 Hold\n0 Sell    MU      80.7200              2
# 4    21\n8 Buy\n9 Hold\n4 Sell  INTC      57.5810              0
# 5   17\n10 Buy\n5 Hold\n2 Sell  NFLX     497.9820              1
# 6   17\n14 Buy\n3 Hold\n0 Sell   DRI     121.0820              1
# 7   17\n11 Buy\n5 Hold\n1 Sell  SRPT      90.3200              1
# 8    16\n5 Buy\n9 Hold\n2 Sell  TSLA     826.1618              0
# 9   15\n1 Buy\n14 Hold\n0 Sell  CHNG      24.0000              0
# 10  15\n11 Buy\n4 Hold\n0 Sell   STZ     219.9930              1
# 11  14\n4 Buy\n10 Hold\n0 Sell  TWTR      45.1800              1
# 12   13\n6 Buy\n5 Hold\n2 Sell  AAPL     127.1410              1
# 13   13\n6 Buy\n6 Hold\n1 Sell    LB      45.2000              1
# 14  13\n12 Buy\n1 Hold\n0 Sell  PANW     364.8710              2
# 15   13\n4 Buy\n9 Hold\n0 Sell  DASH     187.1520              1
# 16   13\n7 Buy\n6 Hold\n0 Sell    ZS     211.0610              1
# 17  12\n12 Buy\n0 Hold\n0 Sell  BABA     243.4600              2
# 18   12\n9 Buy\n3 Hold\n0 Sell  FIVE     189.8140              2
# 19  12\n11 Buy\n1 Hold\n0 Sell  PTON     157.8170              2
# 20  11\n10 Buy\n1 Hold\n0 Sell   IAC     197.6610              2

# %% [markdown]
# # SCATTER PLOT:
# - Actual Market Price and Target Price

# %%
import seaborn as sns; sns.set()

# MARKER size based on the PRICE 
shp=[20*j for j in range(20) ]

# %%
plt.scatter(df_stock_rec['stock'], df_stock_rec['Price_Target'], color='b',s= shp, label='Price_Target')
plt.scatter(df_stock_rec['stock'], df_stock_rec['Daily_price'], color='r', label='Acutal/Daily Price')
plt.legend(loc="upper right", fontsize=15)
plt.gcf().set_size_inches(12,7)
plt.yticks(np.arange(0,900, 50))
plt.xticks(rotation= 75, fontsize=15);
