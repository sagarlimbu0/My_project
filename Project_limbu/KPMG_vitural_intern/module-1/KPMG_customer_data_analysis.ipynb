# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# to read the image for terms and std dimensionality
from PIL import Image

# %% [markdown]
# # OBJECTIVE:
# - Sprocket Central Pty Ltd needs help with customer and transations data
# - The goranizatin has a large datasetrelating to tis cutomers, but UNSURE how to
#     effictively ANALYSE to help optimise its marketing strategy
# - Optimising the Quality of customer DATASETS

# %%
files= os.listdir(r'.')
for i in files:
    if i.endswith('.xlsx'):
        print(i)
# Out:
# customer_address.xlsx
# customer_demographics.xlsx
# KPMG_VI_New_raw_data_update_final.xlsx
# KPMG_VI_New_raw_data_update_NEW.xlsx
# new_customer_list.xlsx
# transaction.xlsx
# ~$KPMG_VI_New_raw_data_update_final.xlsx
# ~$transaction.xlsx

# %%
df_sp_raw= pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx')

# %%
df_sp_raw.head(4)
# Out:
#    Unnamed: 0  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
#
#    Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#                 Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0                      NaN         NaN         NaN        NaN         NaN
# 1                      NaN         NaN         NaN        NaN         NaN
# 2                      NaN         NaN         NaN        NaN         NaN
# 3  KPMG Virtual Internship         NaN         NaN        NaN         NaN
#
#    Unnamed: 7 Unnamed: 8  Unnamed: 9  Unnamed: 10
# 0         NaN        NaN         NaN          NaN
# ...

# %% [markdown]
# # READING multiple sheets from the Given Excel file.
# # By using the 'Data Quality Framework'
# - Transactions
# - New Customer List
# - Customer Demographics
# - Customer Address

# %%
df_trans= pd.read_excel('transaction.xlsx')
df_new_cust= pd.read_excel('new_customer_list.xlsx')
df_cust_dem= pd.read_excel('customer_demographics.xlsx')
df_cust_addr= pd.read_excel('customer_address.xlsx')

# %%
df_trans.head(4)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
#
#    list_price  standard_cost  product_first_sold_date
# 0       71.49          53.62                  41245.0
# 1     2091.47         388.92                  41701.0
# 2     1793.43         248.82                  36361.0
# ...

# %%
df_trans.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
df_cust_dem.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
df_new_cust.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value'],
#       dtype='object')

# %%
df_cust_addr.columns
# Out:
# Index(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %% [markdown]
# # 1. Anayzing the Customer demographics
# # Objective: cluster analysis of the demographics of customers

# %%
df_cust_dem.head(4)
# Out:
#    customer_id first_name  last_name gender  \
# 0            1    Laraine  Medendorp      F
# 1            2        Eli    Bockman   Male
# 2            3      Arlin     Dearle   Male
# 3            4     Talbot        NaN   Male
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
#
#   job_industry_category wealth_segment deceased_indicator  \
# 0                Health  Mass Customer                  N
# 1    Financial Services  Mass Customer                  N
# 2              Property  Mass Customer                  N
# 3                    IT  Mass Customer                  N
#
#                                              default owns_car  tenure
# ...

# %%
df_cust_dem.DOB.describe()
# Out:
# count                    3913
# unique                   3448
# top       1978-01-30 00:00:00
# freq                        7
# first     1843-12-21 00:00:00
# last      2002-03-11 00:00:00
# Name: DOB, dtype: object

# %%
customer_dem=['customer_id',
       'first_name',
       'last_name',
       'gender',
       'past_3_years_bike_related_purchases',
       'DOB',
       'job_title',
       'job_industry_category',
       'wealth_segment',
       'deceased_indicator',
       'default',
       'owns_car',
       'tenure']

# %%
customer_dem
# Out:
# ['customer_id',
#  'first_name',
#  'last_name',
#  'gender',
#  'past_3_years_bike_related_purchases',
#  'DOB',
#  'job_title',
#  'job_industry_category',
#  'wealth_segment',
#  'deceased_indicator',
#  'default',
#  'owns_car',
#  'tenure']

# %%
# list out any UNIQUE values from the data Frame

for i in range(0, len(customer_dem)):
    
    print(customer_dem[i],":", df_cust_dem[customer_dem[i]].unique(),"\n")
    print("***************************************************************")
# Out:
# customer_id : [   1    2    3 ... 3998 3999 4000]
#
# ***************************************************************
# first_name : ['Laraine' 'Eli' 'Arlin' ... 'Stephie' 'Rusty' 'Sarene']
#
# ***************************************************************
# last_name : ['Medendorp' 'Bockman' 'Dearle' ... 'Halgarth' 'Woolley' 'Oldland']
#
# ***************************************************************
# gender : ['F' 'Male' 'Female' 'U' 'Femal' 'M']
#
# ***************************************************************
# past_3_years_bike_related_purchases : [93 81 61 33 56 35  6 31 97 49 99 58 38 85 91 57 79 76 72 74 43 55 12 37
#   5 62 18  3 17 44 59 40 46 64 24 63 98 51 68 22  2 48 87 26 60 47 73 21
#  67 16 78 30 94 28 20 11  1 75 41 69 19 80 83 25 54  4 23 65 88 10 77  9
#  82 27 53 32 34 71 36 90 95  8 39  7 42 13 45 50 14 89 84 96 70 66  0 15
#  86 92 29 52]
#
# ***************************************************************
# ...

# %%
df_cust_dem['gender'].unique()
# Out:
# array(['F', 'Male', 'Female', 'U', 'Femal', 'M'], dtype=object)

# %%
df_cust_dem[df_cust_dem['gender'].values == 'Femal']
# Out:
#     customer_id first_name last_name gender  \
# 53           54    Loralyn    Wonfor  Femal
#
#     past_3_years_bike_related_purchases        DOB        job_title  \
# 53                                    2 1966-07-24  Sales Associate
#
#    job_industry_category wealth_segment deceased_indicator default owns_car  \
# 53              Property  Mass Customer                  N    -0.5      Yes
#
#     tenure
# 53    18.0

# %%
min(df_cust_dem.DOB), max(df_cust_dem.DOB)
# Out:
# (Timestamp('1843-12-21 00:00:00'), Timestamp('2002-03-11 00:00:00'))

# %%
# FINDING the Earliest DOB of a customer

df_cust_dem.DOB[df_cust_dem.DOB.values == min(df_cust_dem.DOB)]
# Out:
# Series([], Name: DOB, dtype: datetime64[ns])

# %%
# Checking if the customer ID has any duplicates

(df_cust_dem.customer_id.duplicated()).count()
# Out:
# 4000

# %%
# Checking for NAN values from the column

for i in range(0, len(customer_dem)):
    print(customer_dem[i],":", df_cust_dem[customer_dem[i]].isnull().sum())
# Out:
# customer_id : 0
# first_name : 0
# last_name : 125
# gender : 0
# past_3_years_bike_related_purchases : 0
# DOB : 87
# job_title : 506
# job_industry_category : 656
# wealth_segment : 0
# deceased_indicator : 0
# default : 302
# owns_car : 0
# tenure : 87

# %% [markdown]
# # Cleaning the Transactions

# %%
df_trans.head(3)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
#
#   order_status          brand product_line product_class product_size  \
# 0     Approved          Solex     Standard        medium       medium
# 1     Approved  Trek Bicycles     Standard        medium        large
# 2     Approved     OHM Cycles     Standard           low       medium
#
#    list_price  standard_cost  product_first_sold_date
# 0       71.49          53.62                  41245.0
# 1     2091.47         388.92                  41701.0
# 2     1793.43         248.82                  36361.0

# %%
df_trans.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
# Find any missing values on each COLUMNS

for i in range(len(df_trans.columns)):
    print(df_trans.columns[i], ':', df_trans[df_trans.columns[i]].isnull().sum())
# Out:
# transaction_id : 0
# product_id : 0
# customer_id : 0
# transaction_date : 0
# online_order : 360
# order_status : 0
# brand : 197
# product_line : 197
# product_class : 197
# product_size : 197
# list_price : 0
# standard_cost : 197
# product_first_sold_date : 197

# %%
df_trans.sort_values(by=["standard_cost"], ascending= True).head(5)
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 2222             2223          19         1067       2017-01-22           1.0
# 2358             2359          19         3352       2017-09-03           0.0
# 8077             8078          19         2898       2017-09-14           1.0
# 15778           15779           0           88       2017-07-12           0.0
# 10191           10192          19         1370       2017-11-27           1.0
#
#       order_status       brand product_line product_class product_size  \
# 2222      Approved  OHM Cycles         Road          high        large
# 2358      Approved  OHM Cycles         Road          high        large
# 8077      Approved  OHM Cycles         Road          high        large
# 15778     Approved  OHM Cycles         Road          high        large
# 10191     Approved  OHM Cycles         Road          high        large
#
#        list_price  standard_cost  product_first_sold_date
# ...

# %%
# Check for ANY unique Values
for i in range(len(df_trans.columns)):
    
    print( df_trans.columns[i],":", df_trans[df_trans.columns[i]].unique(), "\n")
    print("**************************)")
# Out:
# transaction_id : [    1     2     3 ... 19998 19999 20000]
#
# **************************)
# product_id : [  2   3  37  88  78  25  22  15  67  12   5  61  35  16  79  33  54  27
#   82  89  64  19  72  91   1  99   0  92  14  44  76  46  55  66  81  86
#   32  77  96   6  47  94  93  60  28   4  38  56  58  50  80  87  84  21
#   31  62  17  73  45  49  95  18  70  26  39  36  98  75  42  20  24  53
#   65  29  11  10   7  41   9  69  90  97 100  74  71  34  57  23  51  59
#   63  40   8  13  30  48  68  83  43  52  85]
#
# **************************)
# customer_id : [2950 3120  402 ...  130 2789 3446]
#
# **************************)
# transaction_date : ['2017-02-25T00:00:00.000000000' '2017-05-21T00:00:00.000000000'
#  '2017-10-16T00:00:00.000000000' '2017-08-31T00:00:00.000000000'
#  '2017-10-01T00:00:00.000000000' '2017-03-08T00:00:00.000000000'
#  '2017-04-21T00:00:00.000000000' '2017-07-15T00:00:00.000000000'
#  '2017-08-10T00:00:00.000000000' '2017-08-30T00:00:00.000000000'
# ...

# %%
df_trans.product_first_sold_date[:5]
# Out:
# 0    41245.0
# 1    41701.0
# 2    36361.0
# 3    36145.0
# 4    42226.0
# Name: product_first_sold_date, dtype: float64

# %%
df_trans.product_line.unique()
# Out:
# array(['Standard', 'Road', 'Mountain', 'Touring', nan], dtype=object)

# %%
max(df_trans.standard_cost), min(df_trans.standard_cost)
# Out:
# (1759.85, 7.21)

# %%
df_trans.brand.unique()
# Out:
# array(['Solex', 'Trek Bicycles', 'OHM Cycles', 'Norco Bicycles',
#        'Giant Bicycles', 'WeareA2B', nan], dtype=object)

# %%
# Checking for any Duplicate values

for i in range(len(df_trans.columns)):
    print (df_trans.columns[i],":", df_trans[df_trans.columns[i]].duplicated().any())
    print("****************************************")
# Out:
# transaction_id : False
# ****************************************
# product_id : True
# ****************************************
# customer_id : True
# ****************************************
# transaction_date : True
# ****************************************
# online_order : True
# ****************************************
# order_status : True
# ****************************************
# brand : True
# ****************************************
# product_line : True
# ****************************************
# product_class : True
# ****************************************
# product_size : True
# ****************************************
# list_price : True
# ****************************************
# standard_cost : True
# ****************************************
# product_first_sold_date : True
# ****************************************

# %%
df_trans[df_trans.standard_cost.duplicated()]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 14                 15          12          247       2017-06-11           0.0
# 15                 16           3         2961       2017-10-10           0.0
# 18                 19          54         2268       2017-04-06           1.0
# 19                 20          25         3002       2017-01-28           1.0
# 21                 22          37          595       2017-06-29           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
# Analyze the customer address
df_cust_addr.head(4)
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4

# %%
# finding any missing values on the Customer Adress
for i in range(len(df_cust_addr.columns)):
    print (df_cust_addr.columns[i],":", df_cust_addr[df_cust_addr.columns[i]].isnull().sum())
    print("****************************************")
# Out:
# customer_id : 0
# ****************************************
# address : 0
# ****************************************
# postcode : 0
# ****************************************
# state : 0
# ****************************************
# country : 0
# ****************************************
# property_valuation : 0
# ****************************************

# %%
# Checking any duplicates

for i in range(len(df_cust_addr.columns)):
    print (df_cust_addr.columns[i],":", df_cust_addr[df_cust_addr.columns[i]].duplicated().any())
    print("****************************************")
# Out:
# customer_id : False
# ****************************************
# address : True
# ****************************************
# postcode : True
# ****************************************
# state : True
# ****************************************
# country : True
# ****************************************
# property_valuation : True
# ****************************************

# %%
df_cust_addr[df_cust_addr['address'].duplicated()]
# Out:
#       customer_id                  address  postcode state    country  \
# 2470         2475         3 Talisman Place      4017   QLD  Australia
# 2980         2985  3 Mariners Cove Terrace      2216   NSW  Australia
# 3535         3540   64 Macpherson Junction      4061   QLD  Australia
#
#       property_valuation
# 2470                   5
# 2980                  10
# 3535                   8

# %%
df_cust_addr[df_cust_addr['address'] == '3 Mariners Cove Terrace']
# Out:
#       customer_id                  address  postcode state    country  \
# 2328         2333  3 Mariners Cove Terrace      3108   VIC  Australia
# 2980         2985  3 Mariners Cove Terrace      2216   NSW  Australia
#
#       property_valuation
# 2328                  10
# 2980                  10

# %%
# finding any unique Values from the customer address
for i in range(len(df_cust_addr.columns)):
    print (df_cust_addr.columns[i],":", df_cust_addr[df_cust_addr.columns[i]].unique())
    print("****************************************")
# Out:
# customer_id : [   1    2    4 ... 4001 4002 4003]
# ****************************************
# address : ['060 Morning Avenue' '6 Meadow Vale Court' '0 Holy Cross Court' ...
#  '87 Crescent Oaks Alley' '8194 Lien Street' '320 Acker Drive']
# ****************************************
# postcode : [2016 2153 4211 2448 3216 2210 2650 2023 3044 4557 3799 2760 2428 3331
#  3058 2135 2233 2444 4413 4740 3218 4868 4116 2519 2756 2170 4005 4127
#  2535 4726 4805 2212 2207 3350 3931 4018 4670 2480 3212 2322 3198 2047
#  4503 2145 4350 2142 2029 2127 4280 2166 2046 2026 2765 2749 2745 3752
#  2217 2230 3046 3183 2070 2213 4208 2774 4133 4213 4170 2073 3561 2330
#  3977 2204 2086 2226 2075 2038 2069 2100 3133 3070 2777 2125 2766 2209
#  2160 2065 2150 2168 4171 2155 2517 2096 2750 2093 3204 4300 3844 4226
#  3192 2485 2097 4817 2516 3074 4508 4405 2452 2205 4132 4744 2158 3201
#  4178 2112 2033 4401 3186 4017 2315 2285 2219 4509 2759 2747 2227 2025
# ...

# %%
#property valuation of 11

df_cust_addr[df_cust_addr['property_valuation'] == 11]
# Out:
#       customer_id                 address  postcode            state  \
# 25             30     02663 Buell Parkway      2519  New South Wales
# 79             84   96061 Ludington Place      2086  New South Wales
# 80             85  5037 Merchant Crossing      2226  New South Wales
# 81             86         289 Haas Street      2075  New South Wales
# 84             89     73042 Roth Crossing      2100  New South Wales
# ...           ...                     ...       ...              ...
# 3952         3957   85999 Cherokee Street      2086              NSW
# 3967         3972      08 Dennis Crossing      3184              VIC
# 3972         3977     327 Loeprich Street      3187              VIC
# 3983         3988        565 Bunting Park      2076              NSW
# 3987         3992         8 Randy Parkway      2209              NSW
#
#         country  property_valuation
# 25    Australia                  11
# 79    Australia                  11
# ...

# %%
df_cust_addr[df_cust_addr.address.str.startswith('0 ')]
# Out:
#       customer_id                 address  postcode            state  \
# 2               4      0 Holy Cross Court      4211              QLD
# 107           112         0 David Terrace      3204              VIC
# 122           127      0 Pearson Crossing      4405              QLD
# 133           138  0 Golden Leaf Crossing      2033  New South Wales
# 152           157       0 Hazelcrest Road      3025              VIC
# ...           ...                     ...       ...              ...
# 3723         3728    0 Declaration Center      2250              NSW
# 3859         3864        0 Arapahoe Court      4305              QLD
# 3904         3909       0 Darwin Junction      2747              NSW
# 3917         3922      0 Southridge Drive      4311              QLD
# 3991         3996      0 Transport Center      3977              VIC
#
#         country  property_valuation
# 2     Australia                   9
# 107   Australia                  11
# ...
