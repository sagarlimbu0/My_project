# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

# %%
url='https://www.imdb.com/chart/toptv/'

browser= webdriver.Chrome()
browser.get(url)

# %%
# create a SELF class INSTANCE that will iterate the OBJECT
class atleast_one_obj(object):
    
    def __init__(self, locator, n):
        
        self.locator= locator
        self.n= n
        
    # CALL function
    def __call__(self, browser):
        
        elements= browser.find_elements(*self.locator)
        
        # compare the len with elements
        if len(elements) >= self.n:
            return elements
        else:
            return False

# %%
# ITERATE over the browser by finding elements

# state the IMPLICIT waiting TIME before moving to next elements
browser.implicitly_wait(10)

# %%
# STATE the main ELEMENT of the WEB page
div_element= browser.find_element_by_class_name('lister')

# NOW LOCATE the class name using 'BY' method
name_locator= (By.CLASS_NAME,'titleColumn')

# num of counts per WEB element
class_counts=0

# %%
# STATE the CONDITION when searching

# create a list to store the element
my_series= []

# CONDITION apply
while True:
    
    # actions to scroll to Bootm using action chain
    
    action_chain= ActionChains(browser)
    
    # move to our blocks
    action_chain.move_to_element(div_element)
    
    # click to give it FOCUS
    action_chain.click()
    
    # press the page down key about 10 ten times
    action_chain.send_keys([Keys.PAGE_DOWN for i in range(10)])
    
    # do these actions
    action_chain.perform()
    
    # try to FETCH at least some QUOTES
    try:
        series_name= WebDriverWait(browser,3).until(
            # now serach by the LOACTOR 
            atleast_one_obj(name_locator, class_counts +1)
        )
    except:
        print("..done !!")
        break

    # FINISH iterating to bottom of page else UPDATE
    class_counts= len(series_name)
    
    for series in series_name:
        print(series.text)
# Out:
# 1. Planet Earth II (2016)
# 2. Planet Earth (2006)
# 3. Band of Brothers (2001)
# 4. Breaking Bad (2008)
# 5. Chernobyl (2019)
# 6. The Wire (2002)
# 7. Blue Planet II (2017)
# 8. Our Planet (2019)
# 9. Cosmos: A Spacetime Odyssey (2014)
# 10. Cosmos (1980)
# 11. Game of Thrones (2011)
# 12. Avatar: The Last Airbender (2005)
# 13. Rick and Morty (2013)
# 14. The Sopranos (1999)
# 15. The Last Dance (2020)
# 16. The World at War (1973)
# 17. Scam 1992: The Harshad Mehta Story (2020)
# 18. Life (2009)
# 19. Fullmetal Alchemist: Brotherhood (2009)
# 20. The Vietnam War (2017)
# 21. Sherlock (2010)
# 22. The Twilight Zone (1959)
# 23. Human Planet (2011)
# 24. Persona (2018)
# 25. The Blue Planet (2001)
# 26. Batman: The Animated Series (1992)
# 27. The Beatles Anthology (1995)
# 28. Frozen Planet (2011)
# 29. Firefly (2002)
# 30. Dekalog (1989)
# 31. True Detective (2014)
# 32. Death Note (2006)
# 33. The Civil War (1990)
# 34. Apocalypse: The Second World War (2009)
# 35. Cowboy Bebop (1998)
# 36. Fargo (2014)
# 37. Africa (2013)
# 38. When They See Us (2019)
# 39. Last Week Tonight with John Oliver (2014)
# 40. Hunter x Hunter (2011)
# 41. Only Fools and Horses (1981)
# 42. TVF Pitchers (2015)
# 43. The Office (2005)
# 44. Gravity Falls (2012)
# 45. Friends (1994)
# 46. Das Boot (1985)
# 47. Seinfeld (1989)
# 48. Monty Python's Flying Circus (1969)
# 49. Nathan for You (2013)
# 50. Pride and Prejudice (1995)
# 51. Black Mirror (2011)
# 52. How the Universe Works (2010)
